# %%
import malariagen_data

# %%
ag3 = malariagen_data.Ag3()

# %%
ag3
# Out:
# <MalariaGEN Ag3 data resource API>
# Storage URL           : gs://vo_agam_release/
# Releases available    : 3.0
# Cohorts analysis      : 20211101
# Species analysis      : aim_20200422
# Site filters analysis : dt_20200416
# ---
# Please note that data are subject to terms of use,
# for more information see https://www.malariagen.net/data
# or contact data@malariagen.net.
# ---
# For API documentation see https://malariagen.github.io/vector-data/ag3/api.html

# %%
sets = ag3.sample_sets()
mysets = sets['sample_set'][4:12].to_list()
print(mysets)
sets.head(5)
# Out:
# ['AG1000G-CD', 'AG1000G-CF', 'AG1000G-CI', 'AG1000G-CM-A', 'AG1000G-CM-B', 'AG1000G-CM-C', 'AG1000G-FR', 'AG1000G-GA-A']
#      sample_set  sample_count release
# 0    AG1000G-AO            81     3.0
# 1  AG1000G-BF-A           181     3.0
# 2  AG1000G-BF-B           102     3.0
# 3  AG1000G-BF-C            13     3.0
# 4    AG1000G-CD            76     3.0

# %%
ag3.sample_metadata(sample_sets=mysets)
# Out:
#     sample_id partner_sample_id    contributor  \
# 0    BP0009-C           Gba_1_9  David Weetman
# 1    BP0010-C          Gba_1_10  David Weetman
# 2    BP0011-C          Gba_1_11  David Weetman
# 3    BP0012-C          Gba_1_12  David Weetman
# 4    BP0013-C          Gba_1_13  David Weetman
# ..        ...               ...            ...
# 760  AS0073-C            LIB073     Joao Pinto
# 761  AS0074-C            LIB074     Joao Pinto
# 762  AS0076-C            LIB076     Joao Pinto
# 763  AS0077-C            LIB077     Joao Pinto
# 764  AS0078-C            LIB078     Joao Pinto
#
#                               country    location  year  month  latitude  \
# 0    Democratic Republic of the Congo   Gbadolite  2015      7     4.283
# 1    Democratic Republic of the Congo   Gbadolite  2015      7     4.283
# 2    Democratic Republic of the Congo   Gbadolite  2015      7     4.283
# 3    Democratic Republic of the Congo   Gbadolite  2015      7     4.283
# ...

# %%
snps = ag3.snp_genotypes(region='2L', sample_sets=mysets)

# %%
snps.shape
# Out:
# (48525747, 765, 2)
