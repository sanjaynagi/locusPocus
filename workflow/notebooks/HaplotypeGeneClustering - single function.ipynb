# %%
import numpy as np 
import pandas as pd
import allel
import malariagen_data
# %matplotlib inline

import locusPocus
from locusPocus import log

# %% [markdown]
# ## Coeae1f region haplotype clustering

# %%
ag3 = malariagen_data.Ag3(pre=True)

# %% [markdown]
# ### Load cohorts
#
# Which populations do we want to look at?

# %%
sample_sets = [
    # Ag1000G phase 3 sample sets in Ag3.0
    "AG1000G-GH", 
    'AG1000G-ML-A',
     'AG1000G-BF-A',
     'AG1000G-BF-B',
     'AG1000G-GN-A',
     'AG1000G-GN-B',
    'AG1000G-TZ',
    # Amenta-Etego sample sets in Ag3.3
    # GAARDIAN sample set in Ag3.4
    '1244-VO-GH-YAWSON-VMF00149',
    # GAARD Ghana sample set in Ag3.2
     "1244-VO-GH-YAWSON-VMF00051",
     '1245-VO-CI-CONSTANT-VMF00054',
     '1253-VO-TG-DJOGBENOU-VMF00052',
     '1237-VO-BJ-DJOGBENOU-VMF00050'
]

# %% [markdown]
# ### cluster_haplotypes

# %%
fig = locusPocus.haplotype_cluster(
    contig='2L',
    start=28_545_000, 
    end=28_551_000, 
    sample_sets=['AG1000G-GH', 'AG1000G-BF-A'], 
    sample_query=None, 
    transcript="AGAP006227-RA", 
    analysis="gamb_colu_arab", 
    min_cohort_size=70, 
    cut_height=1)
# Out:
# loading haplotype data store
# Load sample metadata:   0%|          | 0/2 [00:00<?, ?it/s]
# Clustering haplotypes
# retrieving haplotype clusters and spans
# correct order
# aligning haplotype calls to amino acids
# remapping haplotype alleles 0-3
# Computing snp allele frequencies
# Load SNP genotypes:   0%|          | 0/12 [00:00<?, ?it/s]
# Compute allele frequencies:   0%|          | 0/8 [00:00<?, ?it/s]
# Compute SNP effects:   0%|          | 0/7629 [00:00<?, ?it/s]
# intersecting haplotypes and allele frequency data
# There are total 13 amino acid changes with max_af > 0.05 & effect == 'NON_SYNONYMOUS_CODING'
# In the haplotype data, there are 13 amino acid changes with max_af > 0.05 & effect == 'NON_SYNONYMOUS_CODING'
# set up population and species data frames
# generating dendro for plot
# plotting population bar
# plotting species bar
# Drawing heatmap

# %%
fig = locusPocus.haplotype_cluster(
    contig='2L',
    start=2_355_000, 
    end=2_431_000, 
    sample_sets=['AG1000G-GH', 'AG1000G-BF-A'], 
    sample_query=None, 
    transcript="AGAP004707-RD", 
    analysis="gamb_colu", 
    min_cohort_size=30, 
    cut_height=10)
# Out:
# loading haplotype data store
# Clustering haplotypes
# retrieving haplotype clusters and spans
# correct order
# aligning haplotype calls to amino acids
# remapping haplotype alleles 0-3
# Computing snp allele frequencies
# Load SNP genotypes:   0%|          | 0/24 [00:00<?, ?it/s]
# Compute allele frequencies:   0%|          | 0/8 [00:00<?, ?it/s]
# Compute SNP effects:   0%|          | 0/209001 [00:00<?, ?it/s]
# intersecting haplotypes and allele frequency data
# There are total 12 amino acid changes with max_af > 0.05 & effect == 'NON_SYNONYMOUS_CODING'
# In the haplotype data, there are 12 amino acid changes with max_af > 0.05 & effect == 'NON_SYNONYMOUS_CODING'
# set up population and species data frames
# generating dendro for plot
# plotting population bar
# plotting species bar
# Drawing heatmap
# Shading large haplotype clusters

# %%
fig = locusPocus.haplotype_cluster(
    contig='2L',
    start=2_355_000, 
    end=2_431_000, 
    sample_sets=['AG1000G-GH', 'AG1000G-UG'], 
    sample_query=None, 
    transcript="AGAP004707-RD", 
    analysis="gamb_colu", 
    min_cohort_size=30, 
    cut_height=10,
    shade_clusters=False)
# Out:
# loading haplotype data store
# Load sample metadata:   0%|          | 0/2 [00:00<?, ?it/s]
# /home/sanj/miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# Clustering haplotypes
# retrieving haplotype clusters and spans
# correct order
# aligning haplotype calls to amino acids
# remapping haplotype alleles 0-3
# Computing snp allele frequencies
# Load SNP genotypes:   0%|          | 0/32 [00:00<?, ?it/s]
# Compute allele frequencies:   0%|          | 0/10 [00:00<?, ?it/s]
# Compute SNP effects:   0%|          | 0/209001 [00:00<?, ?it/s]
# intersecting haplotypes and allele frequency data
# There are total 12 amino acid changes with max_af > 0.05 & effect == 'NON_SYNONYMOUS_CODING'
# In the haplotype data, there are 12 amino acid changes with max_af > 0.05 & effect == 'NON_SYNONYMOUS_CODING'
# /home/sanj/miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# set up population and species data frames
# generating dendro for plot
# plotting population bar
# plotting species bar
# Drawing heatmap
